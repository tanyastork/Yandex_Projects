# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузим-данные-и-подготовим-их-к-анализу" data-toc-modified-id="Загрузим-данные-и-подготовим-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузим данные и подготовим их к анализу</a></span><ul class="toc-item"><li><span><a href="#Visits" data-toc-modified-id="Visits-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Visits</a></span></li><li><span><a href="#Orders" data-toc-modified-id="Orders-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Orders</a></span></li><li><span><a href="#Expenses" data-toc-modified-id="Expenses-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Expenses</a></span></li></ul></li><li><span><a href="#Зададим-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Зададим-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Зададим функции для расчёта и анализа LTV, ROI, удержания и конверсии.</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Составим-профили-пользователей.-Определим-минимальную-и-максимальную-даты-привлечения-пользователей." data-toc-modified-id="Составим-профили-пользователей.-Определим-минимальную-и-максимальную-даты-привлечения-пользователей.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей.</a></span></li><li><span><a href="#Выясним,-из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей." data-toc-modified-id="Выясним,-из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.</a></span></li><li><span><a href="#Узнаем,-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи." data-toc-modified-id="Узнаем,-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.</a></span></li><li><span><a href="#Изучим-рекламные-источники-привлечения-и-определим-каналы,-из-которых-пришло-больше-всего-платящих-пользователей." data-toc-modified-id="Изучим-рекламные-источники-привлечения-и-определим-каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-расходы-на-маркетинг" data-toc-modified-id="Посмотрим-на-расходы-на-маркетинг-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посмотрим на расходы на маркетинг</a></span></li><li><span><a href="#Узнаем,-сколько-в-среднем-стоило-привлечение-одного-пользователя-(CAC)-из-каждого-источника." data-toc-modified-id="Узнаем,-сколько-в-среднем-стоило-привлечение-одного-пользователя-(CAC)-из-каждого-источника.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.</a></span></li></ul></li><li><span><a href="#Оценим-окупаемость-рекламы" data-toc-modified-id="Оценим-окупаемость-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценим окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Проанализируем-окупаемость-рекламы." data-toc-modified-id="Проанализируем-окупаемость-рекламы.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы.</a></span></li><li><span><a href="#Проверим-конверсию-и-удержание-пользователей" data-toc-modified-id="Проверим-конверсию-и-удержание-пользователей-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проверим конверсию и удержание пользователей</a></span></li><li><span><a href="#Проверим-удержание-пользователей-по-каналам-привлечения-пользователей,-по-странам-и-по-устройствам." data-toc-modified-id="Проверим-удержание-пользователей-по-каналам-привлечения-пользователей,-по-странам-и-по-устройствам.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Проверим удержание пользователей по каналам привлечения пользователей, по странам и по устройствам.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам.-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по устройствам.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам.-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по рекламным каналам.</a></span></li><li><span><a href="#Рассмотрим-показатели-в-США" data-toc-modified-id="Рассмотрим-показатели-в-США-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Рассмотрим показатели в США</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Анализ бизнес-показателей развлекательного приложения Procrastinate Pro+

# %% [markdown]
# **Заказчик:**
#
# Приложение Procrastinate Pro+

# %% [markdown]
# **Цель проекта:**
#
# Проанализировать маркетинговую стратегию приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Наша задача — разобраться в причинах и помочь компании выйти в плюс.

# %% [markdown]
# **Входные данные:**
#
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - выгрузка их покупок за этот период: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - рекламные расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# **Структура visits_info_short.csv:**
# - User Id— уникальный идентификатор пользователя,
# - Region— страна пользователя,
# - Device— тип устройства пользователя,
# - Channel— идентификатор источника перехода,
# - Session Start— дата и время начала сессии,
# - Session End— дата и время окончания сессии.
#
# **Структура orders_info_short.csv:**
# - User Id— уникальный идентификатор пользователя,
# - Event Dt— дата и время покупки,
# - Revenue— сумма заказа.
#
# **Структура costs_info_short.csv:**
# - dt — дата проведения рекламной кампании,
# - hannel— идентификатор рекламного источника,
# - costs— расходы на эту кампанию.

# %% [markdown]
# ## 1. Загрузим данные и подготовим их к анализу

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %% [markdown]
# #### Visits

# %%
visits = pd.read_csv('/datasets/visits_info_short.csv')
display(visits.head())
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
visits.duplicated().sum()
# Out:
# 0

# %%
#проверим неявные дубликаты
visits['Region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visits['Device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
visits['Channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %% [markdown]
# В данных с визитами клиентов пропусков  и явных дубликатов нет. Также нет неявных будикатов в столбцах со страной, утсройством и каналом привлечения. Однако с типами данных проблемы: поля Session Start и Session End нужно привести к типу datetime.

# %%
visits['Session Start'] = pd.to_datetime(visits['Session Start'])
visits['Session End'] = pd.to_datetime(visits['Session End'])

# %%
#проверим, что Session Start < Session End 
check = visits['Session Start'] <= visits['Session End']
check.sum()
# Out:
# 309901

# %% [markdown]
# Сумма столбцов, где Session Start < Session End (True=1) совпадает с количеством строчек в этих столбцах, а значит условие верно для всех строк.

# %% [markdown]
# #### Orders

# %%
orders = pd.read_csv('/datasets/orders_info_short.csv')
display(orders.head())
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
orders.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Пропусков и явных дубликатов в данных с заказами нет. Однако Event Dt нужно перевести в datetime.

# %%
orders['Event Dt'] = pd.to_datetime(orders['Event Dt'])

# %%
#проверим, нет ли аномалий в числовых значениях Revenue
orders['Revenue'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Есть как очень большие заказы, так и довольно маленькие. В целом, аномальных и ошибочных значений (например, отрицательных) нет. Однако распределны значения довольно странно. Заказы представлены дискретными данными - есть несколько групп по стоимости, это можно проверить:

# %%
orders['Revenue'].unique()
# Out:
# array([ 4.99,  5.99,  9.99, 49.99, 19.99])

# %% [markdown]
# Видимо, это разные по наполнению подписки

# %% [markdown]
# #### Expenses

# %%
expenses = pd.read_csv('/datasets/costs_info_short.csv')

# %%
expenses.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
expenses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
expenses.duplicated().sum()
# Out:
# 0

# %% [markdown]
# В таблице с расходами пропусков и явных дубликатов нет. Изменим тип данных столбца dt.

# %%
expenses['dt'] = pd.to_datetime(expenses['dt']).dt.date

# %%
#проверим, нет ли аномалий в числовых значениях costs
expenses['costs'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# В столбце с затратами на реклму аномалий нет.

# %%
#проверим пересечения одинаковых столбцов в разных таблицах
list(set(expenses['Channel'].unique()) ^ set(visits['Channel'].unique()))
# Out:
# ['organic']

# %% [markdown]
# Датасет с визитами пользователей и затратами на рекламную кампанию не совпадают всего по одному каналу привлечения - organic. Это логично, так как в таблице с затратами на рекламу не должно быть органических пользователей, ведь они бесплатны.

# %%
# приведение имен столбцов к snake_case
for i in [visits, orders, expenses]:
    i.columns = [x.lower().replace(' ', '_') for x in i.columns.values]

# %% [markdown]
# Была выполнена предоработка данных. Дубликатов в таблицах нет, были изменены типы данных столбцов с датой на datetime для дальнейшей работы. Также проверены столбцы с числовыми значениями на аномалии, которых не оказалось. Пересечения одинаковых столбцов в таблицах с визитами пользователей и затратами на рекламную кампанию показло отстутсвие 'organic', что является ожидаемым результатом.

# %% [markdown]
# ## 2. Зададим функции для расчёта и анализа LTV, ROI, удержания и конверсии.

# %%
#функция для разделения пользователей на когорты
def get_profiles(sessions, orders, costs):
    # находим параметры первых посещений
    profiles = (sessions.sort_values(by=['user_id', 'session_start'])
                .groupby('user_id')
                .agg(
                    {
                        'session_start' : 'first',
                        'channel' : 'first',
                        'device' : 'first',
                        'region' : 'first'
                    }
                )
                .rename(columns={'session_start' : 'first_ts'})
                .reset_index()
               )
    
    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    
    # добавляем признак пользователей, совершивших покупку
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())
    
    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )
    
    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = costs.merge(new_users, on=['dt', 'channel'], how='left')
    
    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    
    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
    
    return profiles

# %%
# функция для расчёта удержания, retention rate

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# Функции для построения графиков:

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Были заданы функции для расчёта значений метрик и построения графиков:
#
# Для вычисления значений метрик:
#
# - get_profiles() — для создания профилей пользователей,
# - get_retention() — для подсчёта Retention Rate,
# - get_conversion() — для подсчёта конверсии,
# - get_ltv() — для подсчёта LTV.
#
# Для построения графиков:
#
# - filter_data() — для сглаживания данных,
# - plot_retention() — для построения графика Retention Rate,
# - plot_conversion() — для построения графика конверсии,
# - plot_ltv_roi — для визуализации LTV и ROI.

# %% [markdown]
# ## 3. Исследовательский анализ данных

# %% [markdown]
# #### Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей.

# %%
profiles = get_profiles(visits, orders, expenses)
display(profiles.head())
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
print('Минимальная дата привлечения пользователей:', profiles['first_ts'].min())
print('Максимальная дата привлечения пользователей:', profiles['first_ts'].max())
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01 00:00:41
# Максимальная дата привлечения пользователей: 2019-10-27 23:59:04

# %% [markdown]
# Мы будет использовать для анализа данные за период с 1 мая 2019 года по 27 октября 2019 года,макисмальная и минималшьная даты, когда были привлечены клиенты.

# %% [markdown]
# #### Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.

# %%
#создадим датафреейм только с платящтми пользователями
payers = profiles.query('payer == True')

# %%
#пользователи по регионам
users_by_regions = profiles.groupby('region').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
users_by_regions.columns = ['все пользователи']
users_by_regions['платящие пользователи'] = payers.groupby('region').agg({'user_id': 'nunique'})
users_by_regions.index.name = 'страна'
users_by_regions
# Out:
#                все пользователи  платящие пользователи
# страна
# United States            100002                   6902
# UK                        17575                    700
# France                    17450                    663
# Germany                   14981                    616

# %%
#добавим долю
users_by_regions['%платящих'] = round((users_by_regions['платящие пользователи']/users_by_regions['все пользователи'])*100, 2)
display(users_by_regions)
# Out:
#                все пользователи  платящие пользователи  %платящих
# страна
# United States            100002                   6902       6.90
# UK                        17575                    700       3.98
# France                    17450                    663       3.80
# Germany                   14981                    616       4.11

# %%
#построим круговые диаграммы
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']

ax1.bar(users_by_regions.index, users_by_regions['%платящих'], color = 'violet')

ax2.pie(users_by_regions['все пользователи'],  autopct='%1.1f%%', colors=colors)
labels = users_by_regions.index.tolist()
ax2.legend(labels, loc="best")
ax2.set_title('Все пользователи по странам')

plt.show()

# %% [markdown]
# Пользователи обычно приходят из США(66.7%) - это наша основная целевая аудитория. Менее популярен сервис в Великобритании, Франции - 11% и в Германии - 10%.  Большая часть пользователей представляет собой регион США, при этом процент платящих пользователей там - 7%, тогда как в других странах он равен примерно 4%.

# %% [markdown]
# #### Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.

# %%
#пользователи по предпочитаемым устройствам
users_by_device = profiles.groupby('device').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
users_by_device.columns = ['все пользователи']
users_by_device['платящие пользователи'] = payers.groupby('device').agg({'user_id': 'nunique'})
users_by_device.index.name = 'устройство'
users_by_device
# Out:
#             все пользователи  платящие пользователи
# устройство
# iPhone                 54479                   3382
# Android                35032                   2050
# PC                     30455                   1537
# Mac                    30042                   1912

# %%
#добавим долю
users_by_device['%платящих'] = round((users_by_device['платящие пользователи']/users_by_device['все пользователи'])*100, 2)
display(users_by_device)
# Out:
#             все пользователи  платящие пользователи  %платящих
# устройство
# iPhone                 54479                   3382       6.21
# Android                35032                   2050       5.85
# PC                     30455                   1537       5.05
# Mac                    30042                   1912       6.36

# %%
#построим круговые диаграммы
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']

ax1.bar(users_by_device.index, users_by_device['%платящих'], color = 'violet')

ax2.pie(users_by_device['все пользователи'],  autopct='%1.1f%%', colors=colors)
labels = users_by_device.index.tolist()
ax2.legend(labels, loc="best")
ax2.set_title('Пользователи по устройствам')

plt.show()

# %%
#Пользователи США
users_usa = profiles.query('region=="United States"')
usa_grouped = users_usa.groupby('device').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
usa_grouped.columns = ['Кол-во пользователей в США']


#Пользователи UK
users_uk = profiles.query('region=="UK"')
uk_grouped = users_uk.groupby('device').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
uk_grouped.columns = ['Кол-во пользователей в UK']

#Пользователи Германии
users_g = profiles.query('region=="Germany"')
g_grouped = users_g.groupby('device').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
g_grouped.columns = ['Кол-во пользователей в Германии']

#Пользователи Франции
users_f = profiles.query('region=="France"')
f_grouped = users_f.groupby('device').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
f_grouped.columns = ['Кол-во пользователей во Франции']

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

axes[0, 0].pie(usa_grouped['Кол-во пользователей в США'],  autopct='%1.1f%%', colors=colors)
labels = usa_grouped.index.tolist()
axes[0, 0].legend(labels, loc="best")
axes[0, 0].set_title('Пользователи США по устройствам')

axes[0, 1].pie(uk_grouped['Кол-во пользователей в UK'],  autopct='%1.1f%%', colors=colors)
labels = uk_grouped.index.tolist()
axes[0, 1].legend(labels, loc="best")
axes[0, 1].set_title('Пользователи Великобритании по устройствам')

axes[1, 0].pie(g_grouped['Кол-во пользователей в Германии'],  autopct='%1.1f%%', colors=colors)
labels = g_grouped.index.tolist()
axes[1, 0].legend(labels, loc="best")
axes[1, 0].set_title('Пользователи Германии по устройствам')

axes[1, 1].pie(f_grouped['Кол-во пользователей во Франции'],  autopct='%1.1f%%', colors=colors)
labels = f_grouped.index.tolist()
axes[1, 1].legend(labels, loc="best")
axes[1, 1].set_title('Пользователи Франции по устройствам');

# %% [markdown]
# На диаграммах выше можно заметить, что большая часть польователей предпочитают айфоны (36%). После них идут пользователи андроид, у них 23%, чуть менее популярны - устройства Mac и PC (по 20%). Доля платящих пользователей в iPhone, Android и Mac	одинаковая - 6%, у PC немного меньше 5%. \
# Mac и Iphone более популярны в США, а PC и Android в европейских странах.

# %% [markdown]
# #### Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.

# %%
#клиенты по каналам привлечения
users_by_channel = profiles.groupby('channel').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
users_by_channel.columns = ['все пользователи']
users_by_channel['платящие пользователи'] = payers.groupby('channel').agg({'user_id': 'nunique'})
users_by_channel.index.name = 'канал привлечения'
users_by_channel
# Out:
#                     все пользователи  платящие пользователи
# канал привлечения
# organic                        56439                   1160
# FaceBoom                       29144                   3557
# TipTop                         19561                   1878
# OppleCreativeMedia              8605                    233
# LeapBob                         8553                    262
# WahooNetBanner                  8553                    453
# RocketSuperAds                  4448                    352
# MediaTornado                    4364                    156
# YRabbit                         4312                    165
# AdNonSense                      3880                    440
# lambdaMediaAds                  2149                    225

# %%
#добавим долю
users_by_channel['%платящих'] = round((users_by_channel['платящие пользователи']/users_by_channel['все пользователи'])*100)
users_by_channel = users_by_channel.sort_values(by='%платящих')

# %%
#построим диаграммы
plt.figure(figsize=(20, 5))
plt.bar(users_by_channel.index, users_by_channel['%платящих'], color = 'violet')
plt.show()

colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']
plt.figure(figsize=(20, 5))
plt.pie(users_by_channel['все пользователи'],  autopct='%1.1f%%', colors=colors, labels=users_by_channel.index)
plt.title('Пользователи по каналам привлечения')

plt.show()

# %% [markdown]
# Большинство пользователей приходят сами - 38%, FaceBoom - 20%  на втором месте по привлечению пользователей. Также популярен TipTop - 13%. У FaceBoom наибольшая доля платящих пользователей - 12%, также большая доля у  AdNonSense (11%) и у TipTop	и lambdaMediaAds - по 10%. У остальных источников процент сильно меньше, например organic - всего 2%, хоть и большинство пользователей приходят именно сами. У OppleCreativeMedia, YRabbit, MediaTornado и LeapBob самый маленький процент платящих пользователей.

# %% [markdown]
# Вывод:
# - Больше всего пользователей сервиса живет в США - наш основной рынок. Пользователей из Великобритании, Германии, Франции гораздо меньше.
# - Процент платящих пользователей больше в США - 7%, тогда как в других сттранах он равен 4%.
# - В основном пользователи предпочитают айфоны и чуть меньше - андроид телефоны и Mac. Доля платящих пользователей в iPhone, Android и Mac одинаковая - 6%, у PC немного меньше 5%. Mac и Iphone более популярны в США, а PC и Android в европейских странах.
# - Большинство пользователей приходят сами или из FaceBoom и TipTop, однако говорить об их хорошей окупаемости пока рано. При этом у FaceBoom наибольшая доля платящих пользователей - 12%,  также большая доля у AdNonSense (11%) и у TipTop и lambdaMediaAds, а у тех, кто пришел сам - всего 2%. У OppleCreativeMedia, YRabbit, MediaTornado и LeapBob самый маленький процент платящих пользователей - от 2% до 4%
#
# В целом, можно сделать вывод, что больше всего пользователей приходят из США, пользователи айфонов, из площадок FaceBoom и TipTop. На них, возможно, стоит делать акцент при планировании рекламной кампании, однако окупаемость рекламы с этих площадок еще нужно проверить.

# %% [markdown]
# ## 4. Маркетинг

# %% [markdown]
# #### Посмотрим на расходы на маркетинг

# %%
expenses.head()
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# Посмотрим, сколько денег было потрачено на рекламные кампании.

# %%
round(expenses['costs'].sum())
# Out:
# 105497

# %%
costs_by_channel = expenses.groupby('channel').agg({'costs': 'sum'}).sort_values(by='costs', ascending=False)
costs_by_channel['%'] = round((costs_by_channel['costs']/expenses['costs'].sum()) *100)
costs_by_channel
# Out:
#                        costs     %
# channel
# TipTop              54751.30  52.0
# FaceBoom            32445.60  31.0
# WahooNetBanner       5151.00   5.0
# AdNonSense           3911.25   4.0
# OppleCreativeMedia   2151.25   2.0
# RocketSuperAds       1833.00   2.0
# LeapBob              1797.60   2.0
# lambdaMediaAds       1557.60   1.0
# MediaTornado          954.48   1.0
# YRabbit               944.22   1.0

# %% [markdown]
# Самые дорогие источники рекламы - TipTop и FaceBoom, на них приходится 52% и 31% от всех затрат. Они же и привлекают больше всего пользователей. Самые недорогие для компании рекламные каналы - lambdaMediaAds, MediaTornado и YRabbit.

# %%
expenses['dt'] = pd.to_datetime(expenses['dt'])
expenses['week'] = expenses['dt'].dt.isocalendar().week
expenses['month'] = expenses['dt'].dt.month

# %%
#расходы по месяцам
sources = expenses['channel'].unique()

plt.figure(figsize=(12, 6))

for source in sources:
    source_data = expenses[expenses['channel'] == source]
    grouped_data = source_data.groupby('month').agg({'costs': 'sum'})
    label = source
    plt.plot(grouped_data.index, grouped_data['costs'], label=label)
    
plt.xlabel('Месяц')
plt.ylabel('Расходы')
plt.legend()

plt.title('Динамика изменения расходов во времени по месяцам')
plt.show()

#расходы по неделям
sources = expenses['channel'].unique()

plt.figure(figsize=(12, 6))

for source in sources:
    source_data = expenses[expenses['channel'] == source]
    grouped_data = source_data.groupby('week').agg({'costs': 'sum'})
    label = source
    plt.plot(grouped_data.index, grouped_data['costs'], label=label)
    
plt.xlabel('Неделя')
plt.ylabel('Расходы')
plt.legend()

plt.xticks(range(min(grouped_data.index), max(grouped_data.index)+1, 1))
plt.title('Динамика изменения расходов во времени по неделям')
plt.show()

# %% [markdown]
# По графикам видно, что затраты на TipTop сильно растут и своего пика достигли в сентябре, на 39 неделе (почти 4000). Затраты на faceBoom более стабильны, хотя тоже растут. Расходы на TipTop и faceBoom растут примерно в одно и то же время, резкие скачки заметны на 22, 26 и 39 неделях.

# %% [markdown]
# #### Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.

# %%
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
# средняя стоимость привлечения одного пользователя из каждого источника
profiles.pivot_table(index='channel', values='acquisition_cost', aggfunc='mean').sort_values(by='acquisition_cost', ascending=False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %% [markdown]
# Пользователи из TipTop и FaceBoom не только самые многочисленные, но и самые дорогие. У LeapBob и MediaTornado	самые дешевые пользователи, а у organic они бесплатные (так как приходят сами).

# %%
#график CAC
profiles.pivot_table(
    index='month', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(10, 5))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# Более того, средняя стоимость привлечения одного пользователя из TipTop еще и постоянно растет. Выгодны ли нам такие клиенты?

# %%
#проверим среднюю стоимость привлечения одного пользователя по странам
profiles.pivot_table(index='region', values='acquisition_cost', aggfunc='mean').sort_values(by='acquisition_cost', ascending=False)
# Out:
#                acquisition_cost
# region
# United States          0.909268
# Germany                0.295322
# France                 0.290887
# UK                     0.288393

# %% [markdown]
# Пользователи из США сильно дороже всех остальнгых. Учитывая тот факт, что их больше всех, скорее всего, расходы на них больше, чем нужно. Однако для начала стоит оценить окупаемость рекламы.

# %%
#посмотрим, какие источники привлечения преобладают в каждом отдельном регионе
#Пользователи США
users_usa = profiles.query('region=="United States"')
usa_grouped = users_usa.groupby('channel').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
usa_grouped.columns = ['Кол-во пользователей в США']


#Пользователи UK
users_uk = profiles.query('region=="UK"')
uk_grouped = users_uk.groupby('channel').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
uk_grouped.columns = ['Кол-во пользователей в UK']

#Пользователи Германии
users_g = profiles.query('region=="Germany"')
g_grouped = users_g.groupby('channel').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
g_grouped.columns = ['Кол-во пользователей в Германии']

#Пользователи Франции
users_f = profiles.query('region=="France"')
f_grouped = users_f.groupby('channel').agg({'user_id': 'nunique'}).sort_values(by='user_id', ascending=False)
f_grouped.columns = ['Кол-во пользователей во Франции']

# %%
#построим круговые диаграммы
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

axes[0, 0].pie(usa_grouped['Кол-во пользователей в США'],  autopct='%1.1f%%', colors=colors, labels=usa_grouped.index)
axes[0, 0].set_title('Пользователи США по каналам')

axes[0, 1].pie(uk_grouped['Кол-во пользователей в UK'],  autopct='%1.1f%%', colors=colors, labels=uk_grouped.index)
axes[0, 1].set_title('Пользователи Великобритании по каналам')

axes[1, 0].pie(g_grouped['Кол-во пользователей в Германии'],  autopct='%1.1f%%', colors=colors, labels=g_grouped.index)
axes[1, 0].set_title('Пользователи Германии по каналам')

axes[1, 1].pie(f_grouped['Кол-во пользователей во Франции'],  autopct='%1.1f%%', colors=colors, labels=f_grouped.index)
axes[1, 1].set_title('Пользователи Франции по каналам');

# %% [markdown]
# Во всех рассмтариваемых странах преобладают пользователи, которые пришли сами  - 36-38%. В США FaceBoom(29%) и TipTop(19%) наиболее популярные платформы. Также там есть RocketSuperAds, YRabbit и MediaTornado. На европейском рынке каналы привлечения другие. Так, там популярны WahooNetBanner (17%), OppleCreativeMedia(17%) и LeapBob (17%). Также там есть AdNonSense, lambdaMediaAds.

# %% [markdown]
# **Вывод:**
#
# Общая сумма расходов на маркетинг за рассмтариваемый период составила 105 497. При этом больше всего потрачено на такие рекламные площадки, как TipTop, FaceBoom и WahooNetBanner, у них же и самые высокие средние расходы на рекламу. А самые дешевые MediaTornado	и YRabbit.	Пик расходов на рекламу приходится на сентярь. Расходы на TipTop и faceBoom растут примерно в одно и то же время. \
# Пользователи из TipTop и FaceBoom не только самые многочисленные, но и самые дорогие. У LeapBob и MediaTornado самые дешевые пользователи, а у organic они бесплатные (так как приходят сами). Более того, средняя стоимость привлечения одного пользователя из TipTop еще и постоянно растет. При этом пользователи из США сильно дороже всех остальных. \
# Реклманые источники распределены по странам. Так, в США они одни, а в Европе совсем другие.  В США FaceBoom(29%) и TipTop(19%) наиболее популярные платформы. А в Европе WahooNetBanner (17%), OppleCreativeMedia(17%) и LeapBob (17%).
# Скорее всего площадки TipTop и faceBoom, а также пользователи из США, требуют много затрат и поэтому убыточны. Однако это нужно проверить.

# %% [markdown]
# ## 5. Оценим окупаемость рекламы

# %% [markdown]
# #### Проанализируем окупаемость рекламы.

# %%
#Установим момент и горизонт анализа данных
observation_date = datetime(2019, 11, 1).date() #момент анализа
horizon_days = 14 # горизонт анализа

# %%
#уберем из данных органических пользователей
profiles = profiles.query('channel != "organic"')

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - По графикам видно, что реклама не окупается, линия ROI ниже линии уовня окупаемости.  Общий ROI достигает чуть более 80%.
# - В конце второй недели ROI суть более 60%, реклама перестала окупаться в июле, когда взрос CAC.
# - CAC (стоимость привлечения пользователей) сильно выросла за весь рассматриваемый период.
# - LTV возрастает примерно в середине месяца и потом падает. Возможно, пользователи приносят больше дохода только в начале рекламной кампании.

# %% [markdown]
# #### Проверим конверсию и удержание пользователей

# %% [markdown]
# **Конверсия**

# %%
#посмотрим на конверсию
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days
)

# строим хитмэп по таблице конверсии
plt.figure(figsize=(15, 5))
sns.heatmap(conversion_grouped.drop(columns=['cohort_size']), annot=True, fmt='.2%')
plt.title('Тепловая карта конверсии')
plt.show()

# %% [markdown]
# Конверсия пользователей хорошо растет в начале горизонта анализа, однако к концу рассматриваемого периода уже неактивно, рост совсем небольшой.

# %%
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Это также видно и на графиках конверсии, в начале лайфтайма конверсия активно растет, а потом почти не меняется. К концу второй недели конверсия составила примрено 8%.

# %% [markdown]
# **Удержание**

# %%
#смотрим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Неплатящие пользователи удерживаются гораздо хуже, к концу лайфтайма из них не посещает сайт почти никто. Ситуацию с платящими пользователями сильно лучше.

# %% [markdown]
# #### Проверим удержание пользователей по каналам привлечения пользователей, по странам и по устройствам.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['channel'])

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Как видно на графиках, платящие пользователи из FaceBoom и AdNonSence имеют очень маленькое удержание, которое к концу рассмтариваемого периода равно почти 0. А FaceBoom при этом привлекает очень много пользователей. Более того, в FaceBoom и AdNonSence они одни из самых дорогих. Ситуация для неплатящих пользователей для всех источников одинаково, там проблем нет.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['region'])

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание платящих пользователей в США низкое на фоне других регионов, та ведь это наша основная целевая аудитория. Неплатящие ведут себя одинаково во всех странах.

# %%
#удержание пользователей по устройствам
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['device'])

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание платящих пользоавтелей немного лучше у PC. По удержанию серьёзного различия, как это мы могли видеть для регионов и источников, по устройствам нет.

# %% [markdown]
# #### Проанализируем окупаемость рекламы с разбивкой по устройствам.

# %% [markdown]
# Теперь рассмотрим окупаемость рекламы с разбивкой по устройствам.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions = ['device'])

# строим графики LTV, CAC и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# На графиках видно, что окупаются только  пользователи PC, а остальные устройства (Mac, Iphone и Android) убыточны. Это связано  с растущим CAC для этих устройств. Также видно, что после июля стоимость привлечения пользователей резко возросла, самые дешевые пользователи PC, а самые дорогие Mac и iphone.

# %% [markdown]
# #### Проанализируем окупаемость рекламы с разбивкой по странам

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions = ['region'])

# строим графики LTV, CAC и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# LTV пользователей из США сильно выше всех остальных, значит они приносят больше всего дохода на одного клиента. Однако стоимость рекламы для США очень сильно выросла в июле и пользователи из США не окупаются, ROI для них меньше 70%. Пользователи из других стран окупаются очень хорошо, ROI к концу лайфтайма примерно 150%. По последнему лаййфтайму видно, что как раз примерно в июле пользователи из США перестали окупаться. Скорее всего, дело в слишком больших тратах на рекламу, которая перестала привлекать нужное количество пользователей и приносить доход.

# %% [markdown]
# #### Проанализируем окупаемость рекламы с разбивкой по рекламным каналам.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions = ['channel'])

# строим графики LTV, CAC и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# LTV для lambdaMediaAds и TipTop самый высокий и стабильно растет. Однако траты на рекламу в TipTop нестабильны и постоянно растут, особенно видно, что рост происходит в начале нового месяца. Из-за этого реклама там совсем не окупается, ROI менее 60% для TipTop. Также не окупается реклама в FaceBoom и AdNonSense. У FaceBoom очень плохое удержание пользователей, как было замечено ранее, скорее всего, проблема в этом. Стоит отказаться от таких больших трат на некоторые источники рекламы, особенно TipTop. Они могут приносить много пользователей, однако это приносит убытки. Лучше всего окупается реклама в YRabbit.

# %% [markdown]
# #### Рассмотрим показатели в США

# %% [markdown]
# Так как США - наиболее проблемная зона для окупаемости приложения (именно там используются неокупаемый FaceBoom), то рассмотрим эту страну поподробнее

# %%
#отберем данные только из США
profiles = profiles.query('region=="United States"')

# %%
#проверим удержание по устройствам
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['channel'])

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Как это было выявлпено выше, удержание у американской FaceBoom крайне малов сравнении с остальными каналами привлечения у платящих пользователей. Однако у RocketSuperAds и YRabbit наоброт всё очень хорошо.

# %%
# считаем LTV и ROI по каналам привлечения
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions = ['channel'])

# строим графики LTV, CAC и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По платформам не окпуаются только FaceBoom и TipTop, а вот у остальных каналов ROI более 200%. Затраты на TipTop постоянно растут (растет их CAC), а FaceBoom стабилен, хоть и не окупается. Однако LTV для TipTop довольно высокий, возможео поэтому затраты на рекламу у них повысили, что привело к неокупаемости.

# %%
# считаем LTV и ROI по устройствам
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions = ['device'])

# строим графики LTV, CAC и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По устройствам каких-либо сильных различий в США нет.

# %% [markdown]
# #### Вывод

# %% [markdown]
# - Реклама серсвиса Procrastinate Pro+ не окупается. В июле стоимость привлечения пользователя сильно возросла.
# - У неплатящих пользователей удержание совсем мало - примерно 1-2%. Возможно, неплатящим пользователям нечего делать в приложении и они быстро уходят. \
# - Пользователи из США не окупаются.  Там используют такие рекламные каналы, как FaceBoom и TipTop, которые очень дорогие и неокупаемые. Причина кроется в резко возрастающем CAC для  TipTop.
# - Такие рекламные каналы, как TipTop, FaceBoom и AdNonSense (в Европе) не окупаются. Затраты на TipTop сильно растут каждый месяц. Возможно, стоит откзаться от их рекламных кампаний.
# - Некоторые реклманые площадки, например RocketSuperAds и YRabbit в США и  lambdaMediaAds в Европе, хорошо окупаются и емеют низкий, пока стабильный CAC. Однако на них приходится очень маленький процент реклманых затрат.

# %% [markdown]
# ## 6. Вывод

# %% [markdown]
# Приложения Procrastinate Pro+ столкнулось с убытками на фоне огромных вложений в рекламу.
# Был проеден анализ данных Procrastinate Pro+ (лог сервера с информацией о посещениях сайта, информация о заказах и информация о расходах на рекламу) за период с 1 мая по 27 октября 2019 года. Были выявлены некоторые закономерноси:
# - Сервис очень популярен у пользователей из США, которые предпочитают такие девайсы, как Iphone и Mac, а пользователи из Германии, Франции и Великобритании - Android и PC.
# - Процент платящих пользователей больше в США - 7%, тогда как в других странах он равен 4%. Однако при этом удержание платящих пользователей из этой страны сильно ниже Европы. Поэтому основным рынком для получения прибыли является США.
# - Большинство пользователей приходят сами или из  TipTop и FaceBoom. Однако в то же время пользователи из этих площадок самые дорогие (на них приходится 52% и 31% вот всех рекламных вложений, асредний CAC там составил 2.7 и 1.1 на пользователя). Более того, затраты на TipTop сильно растут и своего пика достигли в сентябре, на 39 неделе (почти 4000). FaceBoom имеет очень маленькое платящих удержание и FaceBoom при этом привлекает очень много пользователей. Возможно, стоит лучше проверить, как именно этот сервис делает рекламу. Траты на рекламу в TipTop нестабильны и постоянно растут, особенно видно, что рост происходит в начале нового месяца. Из-за этого реклама там совсем не окупается, ROI менее 60% для TipTop.
# - Выяснилось, что реклама в принципе совсем не окупается (ROI даже менее 75%). Это происходит из-за пользователей из США, окупаемость которых крайне низкая. Это может происходит из-за низкого удержания пользователей из США, а также высокая стоимость пользователя (CAС).
# - Общая динамика удержания снижается довольно быстро, у неплатящих пользователй она совсем мала - примерно 1-2%. Возможно, неплатящим пользователям нечего делать в приложении и они быстро уходят.
# - Удержание платящих пользоавтелей немного лучше у PC, что вероятно связано с тем, что там не используются каналы с плохим удержанием.
# - У пользователей, привлеченных по FaceBoom, низкое удержание.
#
# Возможно, причина таких плохих показателей ROI  в сльшком больших вложениях в неэффективные рекламаные источнники: TipTop, FaceBoom и AdNonSense. CAC для для их пользователей слишком высокий. Также, например в TipTop, хороший LTV. Из-за этого могла быть допущена ошибка и сильно увеличены затраты на рекламу там, а пользователи вскоре перестали окупаться.
#
# Для отдела маркетинга сформулирован ряд рекомендацй:
# - Сокатить инвестиции в рекламу на TipTop и FaceBoom. Однако не убирать эти источники полностью, так как они все же привлекают много  пользователей, что повышает популярность и узнаваемость приложения, хоть и не приносит прибыли, однако это скорее долгосрочное вложение.
# - Продвинуть приложение на таких площадках, как RocketSuperAds и YRabbit для развития рынка США, где ROI выше всего и стоимость одного клиента одна из самых маленьких.
# - Для Европейского рынка стоит отказаться от убыточной площадки AdNonSense в пользу lambdaMediaAds и MediaTornado, у которых сейчас всего 1% рекламного бюджета. Однако они хорошо окупаются, а CAC один из самых низких.
# - Монетизировать бесплатных пользователей: добавить в приложение рекламу для тех, кто не облачивает подписку. Это поможет заработать на них.
